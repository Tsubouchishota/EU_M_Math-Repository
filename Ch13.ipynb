# %%
# %pip install "scikit-learn>=1.2.0,<1.5.0"
# Out:
# Collecting scikit-learn<1.5.0,>=1.2.0
#   Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in .\.venv\Lib\site-packages (from scikit-learn<1.5.0,>=1.2.0) (2.3.5)
# Requirement already satisfied: scipy>=1.6.0 in .\.venv\Lib\site-packages (from scikit-learn<1.5.0,>=1.2.0) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in .\.venv\Lib\site-packages (from scikit-learn<1.5.0,>=1.2.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in .\.venv\Lib\site-packages (from scikit-learn<1.5.0,>=1.2.0) (3.6.0)
# Using cached scikit_learn-1.4.2-cp311-cp311-win_amd64.whl (10.6 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.2
#     Uninstalling scikit-learn-1.7.2:
#       Successfully uninstalled scikit-learn-1.7.2
# Successfully installed scikit-learn-1.4.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pycaret 3.3.2 requires joblib<1.4,>=1.2.0, but you have joblib 1.5.3 which is incompatible.
# pycaret 3.3.2 requires matplotlib<3.8.0, but you have matplotlib 3.10.9 which is incompatible.
# pycaret 3.3.2 requires numpy<1.27,>=1.21, but you have numpy 2.3.5 which is incompatible.
# pycaret 3.3.2 requires pandas<2.2.0, but you have pandas 2.3.3 which is incompatible.
# pycaret 3.3.2 requires scipy<=1.11.4,>=1.6.1, but you have scipy 1.16.3 which is incompatible.
# sktime 0.26.0 requires numpy<1.27,>=1.21, but you have numpy 2.3.5 which is incompatible.
# sktime 0.26.0 requires pandas<2.2.0,>=1.1, but you have pandas 2.3.3 which is incompatible.

# %%
from pycaret.utils import version
version()
# Out:
# '3.3.2'

# %%
from pycaret.datasets import get_data
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0   0.000000   0.000000           0.24      1
# 1   0.150754   0.000000           0.24      1
# 2   0.000000   0.091398           0.23      1
# 3   0.000000   0.000000           0.00      1
# 4   0.000000   0.000000           0.00      0

# %%
from pycaret.classification import *
clf1 = setup(data, target = 'Purchase', session_id=123)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from pycaret.classification import *
#       2 clf1 = setup(data, target = 'Purchase', session_id=123)
#
# File ~\automl_uv_jupyter_gluon\.venv\Lib\site-packages\pycaret\classification\__init__.py:1
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#       6     check_drift,
#       7     check_fairness,
#       8     compare_models,
#       9     convert_model,
#      10     create_api,
#      11     create_app,
#      12     create_docker,
#      13     create_model,
#      14     dashboard,
#      15     deploy_model,
#      16     ensemble_model,
#      17     evaluate_model,
#      18     finalize_model,
#      19     get_allowed_engines,
#      20     get_config,
#      21     get_current_experiment,
#      22     get_engine,
#      23     get_leaderboard,
#      24     get_logs,
#      25     get_metrics,
#      26     interpret_model,
#      27     load_experiment,
#      28     load_model,
#      29     models,
#      30     optimize_threshold,
#      31     plot_model,
#      32     predict_model,
#      33     pull,
#      34     remove_metric,
#      35     save_experiment,
#      36     save_model,
#      37     set_config,
#      38     set_current_experiment,
#      39     setup,
#      40     stack_models,
#      41     tune_model,
#      42 )
#      43 from pycaret.classification.oop import ClassificationExperiment
#      45 __all__ = [
#      46     "ClassificationExperiment",
#      47     "setup",
#    (...)     86     "check_drift",
#      87 ]
#
# File ~\automl_uv_jupyter_gluon\.venv\Lib\site-packages\pycaret\classification\functional.py:8
#       5 import pandas as pd
#       6 from joblib.memory import Memory
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# File ~\automl_uv_jupyter_gluon\.venv\Lib\site-packages\pycaret\classification\oop.py:17
#      14 from scipy.optimize import shgo
#      16 from pycaret.containers.metrics.classification import get_all_metric_containers
# ---> 17 from pycaret.containers.models.classification import (
#      18     ALL_ALLOWED_ENGINES,
#      19     get_all_model_containers,
#      20     get_container_default_engines,
#      21 )
#      22 from pycaret.internal.display import CommonDisplay
#      23 from pycaret.internal.logging import get_logger
#
# File ~\automl_uv_jupyter_gluon\.venv\Lib\site-packages\pycaret\containers\models\classification.py:19
#      17 import pycaret.containers.base_container
#      18 import pycaret.internal.cuml_wrappers
# ---> 19 from pycaret.containers.models.base_model import (
#      20     ModelContainer,
#      21     leftover_parameters_to_categorical_distributions,
#      22 )
#      23 from pycaret.internal.cuml_wrappers import get_svc_classifier
#      24 from pycaret.internal.distributions import (
#      25     Distribution,
#      26     IntUniformDistribution,
#      27     UniformDistribution,
#      28 )
#
# File ~\automl_uv_jupyter_gluon\.venv\Lib\site-packages\pycaret\containers\models\base_model.py:9
#       7 from pycaret.containers.base_container import BaseContainer
#       8 from pycaret.internal.distributions import CategoricalDistribution
# ----> 9 from pycaret.internal.pycaret_experiment.pycaret_experiment import _PyCaretExperiment
#      10 from pycaret.utils.generic import get_allowed_engines, get_logger
#      13 class ModelContainer(BaseContainer):
#
# File ~\automl_uv_jupyter_gluon\.venv\Lib\site-packages\pycaret\internal\pycaret_experiment\pycaret_experiment.py:10
#       7 import cloudpickle
#       8 import pandas as pd
# ---> 10 import pycaret.internal.patches.sklearn
#      11 import pycaret.internal.patches.yellowbrick
#      12 import pycaret.internal.persistence
#
# File ~\automl_uv_jupyter_gluon\.venv\Lib\site-packages\pycaret\internal\patches\sklearn.py:9
#       6 from sklearn.model_selection._validation import _fit_and_score, _score
#       7 from sklearn.utils import check_random_state
# ----> 9 from pycaret.internal.pipeline import pipeline_predict_inverse_only
#      11 # Monkey patching sklearn.model_selection._search to avoid overflows on windows.
#      12
#      13
#      14 # adapted from https://github.com/scikit-learn/scikit-learn/blob/master/sklearn/utils/_random.pyx
#      15 def _mp_sample_without_replacement(
#      16     n_population: int, n_samples: int, method=None, random_state=None
#      17 ) -> Any:
#
# File ~\automl_uv_jupyter_gluon\.venv\Lib\site-packages\pycaret\internal\pipeline.py:19
#      17 import sklearn.pipeline
#      18 from sklearn.base import clone
# ---> 19 from sklearn.utils import _print_elapsed_time
#      20 from sklearn.utils.metadata_routing import _routing_enabled
#      21 from sklearn.utils.metaestimators import available_if
#
# ImportError: cannot import name '_print_elapsed_time' from 'sklearn.utils' (C:\Users\tsubo\automl_uv_jupyter_gluon\.venv\Lib\site-packages\sklearn\utils\__init__.py)

# %%
best_model = compare_models()

# you can save top models, or manually, like
top3_models = compare_models( n_select=3 )
lda = create_model('lda')
dt = create_model('dt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 best_model = compare_models()
#       2
#       3 # you can save top models, or manually, like
#       4 top3_models = compare_models( n_select=3 )
#
# NameError: name 'compare_models' is not defined

# %%
tuned_model = tune_model(best_model)

# %%
# %pip install "numpy<1.27" "pandas<2.2.0" "scipy<=1.11.4" "matplotlib<3.8.0" "joblib<1.4"
# Out:
# Collecting numpy<1.27
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting pandas<2.2.0
#   Using cached pandas-2.1.4-cp311-cp311-win_amd64.whl.metadata (18 kB)
# Collecting scipy<=1.11.4
#   Using cached scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting matplotlib<3.8.0
#   Using cached matplotlib-3.7.5-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting joblib<1.4
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas<2.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\Lib\site-packages (from pandas<2.2.0) (2026.2)
# Requirement already satisfied: tzdata>=2022.1 in .\.venv\Lib\site-packages (from pandas<2.2.0) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib<3.8.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib<3.8.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\Lib\site-packages (from matplotlib<3.8.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib<3.8.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.venv\Lib\site-packages (from matplotlib<3.8.0) (26.2)
# Requirement already satisfied: pillow>=6.2.0 in .\.venv\Lib\site-packages (from matplotlib<3.8.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in .\.venv\Lib\site-packages (from matplotlib<3.8.0) (3.3.2)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas<2.2.0) (1.17.0)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached pandas-2.1.4-cp311-cp311-win_amd64.whl (10.6 MB)
# Using cached scipy-1.11.4-cp311-cp311-win_amd64.whl (44.1 MB)
# Using cached matplotlib-3.7.5-cp311-cp311-win_amd64.whl (7.5 MB)
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Installing collected packages: numpy, joblib, scipy, pandas, matplotlib
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.3.5
#
#     Uninstalling numpy-2.3.5:
#
#       Successfully uninstalled numpy-2.3.5
#
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#    ---------------------------------------- 0/5 [numpy]
#   Attempting uninstall: joblib
#    ---------------------------------------- 0/5 [numpy]
#     Found existing installation: joblib 1.5.3
#    ---------------------------------------- 0/5 [numpy]
#    -------- ------------------------------- 1/5 [joblib]
#     Uninstalling joblib-1.5.3:
#    -------- ------------------------------- 1/5 [joblib]
#       Successfully uninstalled joblib-1.5.3
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#    -------- ------------------------------- 1/5 [joblib]
#   Attempting uninstall: scipy
#    -------- ------------------------------- 1/5 [joblib]
#     Found existing installation: scipy 1.16.3
#    -------- ------------------------------- 1/5 [joblib]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#     Uninstalling scipy-1.16.3:
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#       Successfully uninstalled scipy-1.16.3
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#    ---------------- ----------------------- 2/5 [scipy]
#   Attempting uninstall: pandas
#    ---------------- ----------------------- 2/5 [scipy]
#     Found existing installation: pandas 2.3.3
#    ---------------- ----------------------- 2/5 [scipy]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#     Uninstalling pandas-2.3.3:
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#       Successfully uninstalled pandas-2.3.3
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#    ------------------------ --------------- 3/5 [pandas]
#   Attempting uninstall: matplotlib
#    ------------------------ --------------- 3/5 [pandas]
#    -------------------------------- ------- 4/5 [matplotlib]
#     Found existing installation: matplotlib 3.10.9
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#     Uninstalling matplotlib-3.10.9:
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#       Successfully uninstalled matplotlib-3.10.9
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    -------------------------------- ------- 4/5 [matplotlib]
#    ---------------------------------------- 5/5 [matplotlib]
#
# Successfully installed joblib-1.3.2 matplotlib-3.7.5 numpy-1.26.4 pandas-2.1.4 scipy-1.11.4
# Note: you may need to restart the kernel to use updated packages.

# %%
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
